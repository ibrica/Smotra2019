# %%
# %matplotlib inline
from pycocotools.coco import COCO
import requests
import numpy as np
import skimage.io as io
import matplotlib.pyplot as plt
import pylab
pylab.rcParams['figure.figsize'] = (8.0, 10.0)

# %%
# !mkdir coco
# !mkdir ./coco/images
# !wget  http://images.cocodataset.org/zips/val2017.zip
# !wget  http://images.cocodataset.org/zips/train2017.zip

# %%
# !cd /home/jovyan/work/coco/images
# !mkdir /home/jovyan/work/coco/images/train
# !mkdir /home/jovyan/work/coco/images/val

# %%
#Odzipaj anotacije u coco folder
# !wget http://images.cocodataset.org/annotations/annotations_trainval2017.zip
# !unzip annotations_trainval2017.zip

# %%
# Ne pokretati, blokirati će notebook (limit) a i nije potrebno sve skinuti
#!unzip ./coco/images/val2017.zip -d ./coco/images/val
#!unzip ./coco/images/train2017.zip -d ./coco/images/train

# %%
def download_hotdog_images(trainOrTest, coco):
    cats = coco.loadCats(coco.getCatIds())
    nms=[cat['name'] for cat in cats]
    # print('COCO categories: \n{}\n'.format(' '.join(nms)))
    catIds = coco.getCatIds(catNms=['hot dog'])
    imgIds = coco.getImgIds(catIds=catIds )
    images = coco.loadImgs(imgIds)
    #print("imgIds: ", imgIds)
    print(trainOrTest + " images nr: ", len(images))
    directory = "data/" + trainOrTest +  "/hotdog/"
    for im in images:
        # print("im: ", im)
        img_data = requests.get(im['coco_url']).content
        with open(directory + im['file_name'], 'wb') as handler:
            handler.write(img_data)

# %%
cocoVal = COCO('coco/annotations/instances_val2017.json')
cocoTrain = COCO('coco/annotations/instances_train2017.json')
"""

# display COCO categories and supercategories
cats = cocoTrain.loadCats(coco.getCatIds())
nms=[cat['name'] for cat in cats]
#print('COCO categories: \n{}\n'.format(' '.join(nms)))

nms = set([cat['supercategory'] for cat in cats])
print('COCO supercategories: \n{}'.format(' '.join(nms)))
"""
# Out:
# loading annotations into memory...
# Done (t=0.39s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=12.85s)
# creating index...
# index created!
# "\n\n# display COCO categories and supercategories\ncats = cocoTrain.loadCats(coco.getCatIds())\nnms=[cat['name'] for cat in cats]\n#print('COCO categories: \n{}\n'.format(' '.join(nms)))\n\nnms = set([cat['supercategory'] for cat in cats])\nprint('COCO supercategories: \n{}'.format(' '.join(nms)))\n"

# %%
download_hotdog_images("test", cocoVal)
download_hotdog_images("train", cocoTrain)
# Out:
# loading annotations into memory...
# Done (t=0.39s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=12.84s)
# creating index...
# index created!

# %%
def download_nothotdog_images(trainOrTest, coco):
    cats = coco.loadCats(coco.getCatIds())
    nms=[cat['name'] for cat in cats]
    # print('COCO categories: \n{}\n'.format(' '.join(nms)))
    catIds = coco.getCatIds(catNms=['pet','banana'])
    imgIds = coco.getImgIds(catIds=catIds )
    images = coco.loadImgs(imgIds)
    #print("imgIds: ", imgIds)
    print(trainOrTest + " images nr: ", len(images))
    limit = 1222 if trainOrTest == 'train' else 51
    directory = "data/" + trainOrTest +  "/nothotdog/"
    count = 0
    for im in images:
        count += 1
        if count > limit:
            break
        print("Spremam: " + im['file_name'])
        img_data = requests.get(im['coco_url']).content
        with open(directory + im['file_name'], 'wb') as handler:
            handler.write(img_data)

# %%
#download_nothotdog_images("test", cocoVal)
download_nothotdog_images('train', cocoTrain)
# Out:
# train images nr:  2243
# Saving: 000000344065.jpg
# Saving: 000000221187.jpg
# Saving: 000000458756.jpg
# Saving: 000000057353.jpg
# Saving: 000000221194.jpg
# Saving: 000000499724.jpg
# Saving: 000000565264.jpg
# Saving: 000000229401.jpg
# Saving: 000000368668.jpg
# Saving: 000000286751.jpg
# Saving: 000000262180.jpg
# Saving: 000000147492.jpg
# Saving: 000000368679.jpg
# Saving: 000000311337.jpg
# Saving: 000000540714.jpg
# Saving: 000000131127.jpg
# Saving: 000000327738.jpg
# Saving: 000000475195.jpg
# Saving: 000000122939.jpg
# Saving: 000000032829.jpg
# Saving: 000000393286.jpg
# Saving: 000000548936.jpg
# Saving: 000000073808.jpg
# Saving: 000000090192.jpg
# Saving: 000000360535.jpg
# Saving: 000000147546.jpg
# Saving: 000000467037.jpg
# Saving: 000000172137.jpg
# Saving: 000000016494.jpg
# Saving: 000000114807.jpg
# Saving: 000000082041.jpg
# Saving: 000000401532.jpg
# Saving: 000000327807.jpg
# Saving: 000000098434.jpg
# Saving: 000000172163.jpg
# Saving: 000000147591.jpg
# ...

# %%
#mv to test
#
